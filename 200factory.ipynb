# %%
import numpy as np
import datetime
import sqlite3 as sql
from prettytable import from_db_cursor
import lib
import data
import tkinter as tk

# %%
path_name='12.db'
path=lib.initial_10tables(path_name,data.area_list)
conn=sql.connect(path_name)
lib.for_vedio(conn,data.area_list,6)
# lib.pt_table(conn,'table_workertoday')
# Out:
# 打开了数据库
# +---------+----------+
# | visitor | area_now |
# +---------+----------+
# +---------+----------+
# 创建成功: table_workertoday
# 创建成功: a1
# 创建成功: a2
# 创建成功: a4
# 创建成功: a6
# 创建成功: a7
# 创建成功: a8
# 创建成功: a9
# 创建成功: a10
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# +---------+-----------+----------+-----------+------------+-------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+-------+------------+------------+-----------+
# |    1    |    wang   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    2    |     ye    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    3    |    liu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    4    |     lu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    7    |    shi    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    8    |     wu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    9    |    xing   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    20   |    sun    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    21   |    chen   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    22   |     mu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    26   |   sheng   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    31   |     tu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    32   |     yu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    33   |     du    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    34   |   huang   |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    35   |    bai    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    37   |     xu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     0     |     0      |       |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+-------+------------+------------+-----------+
#  duplicate
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace  | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# |    1    |    wang   |    1     |     1     |  1593364   | -10:0, |    plan    |    -10     |    None   |
# |    2    |     ye    |    1     |     1     |   39065    | -10:0, |    plan    |    -10     |    None   |
# |    3    |    liu    |    1     |     1     |   40244    | -10:0, |    plan    |    -10     |    None   |
# |    4    |     lu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    7    |    shi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    8    |     wu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    9    |    xing   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    20   |    sun    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    21   |    chen   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    22   |     mu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    26   |   sheng   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    31   |     tu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    32   |     yu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    33   |     du    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    34   |   huang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    35   |    bai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    37   |     xu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# -1536059 dddd
# last time do update area
# -10:0, trace
# now  i do area
#  duplicate
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace  | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# |    1    |    wang   |    1     |     1     |  1593364   | -10:0, |    plan    |    -10     |    None   |
# |    2    |     ye    |    1     |     1     |   39065    | -10:0, |    plan    |    -10     |    None   |
# |    3    |    liu    |    1     |     1     |   40244    | -10:0, |    plan    |    -10     |    None   |
# |    4    |     lu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     1     |  1379105   | -10:0, |    plan    |    -10     |    None   |
# |    8    |     wu    |    2     |     1     |   18409    | -10:0, |    plan    |    -10     |    None   |
# |    9    |    xing   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    20   |    sun    |    7     |     1     |   205120   | -10:0, |    plan    |    -10     |    None   |
# |    21   |    chen   |    7     |     1     |   15149    | -10:0, |    plan    |    -10     |    None   |
# |    22   |     mu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    26   |   sheng   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    31   |     tu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    32   |     yu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    33   |     du    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    34   |   huang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    35   |    bai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    37   |     xu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# -19259 dddd
# last time do update area
# -10:0, trace
# now  i do area
#  duplicate
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace  | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# |    1    |    wang   |    1     |     1     |  1593364   | -10:0, |    plan    |    -10     |    None   |
# |    2    |     ye    |    1     |     1     |   39065    | -10:0, |    plan    |    -10     |    None   |
# |    3    |    liu    |    1     |     1     |   40244    | -10:0, |    plan    |    -10     |    None   |
# |    4    |     lu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     1     |  1379105   | -10:0, |    plan    |    -10     |    None   |
# |    8    |     wu    |    2     |     1     |   18409    | -10:0, |    plan    |    -10     |    None   |
# |    9    |    xing   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    20   |    sun    |    7     |     1     |   205120   | -10:0, |    plan    |    -10     |    None   |
# |    21   |    chen   |    7     |     1     |   15149    | -10:0, |    plan    |    -10     |    None   |
# |    22   |     mu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    26   |   sheng   |    8     |     1     |   115497   | -10:0, |    plan    |    -10     |    None   |
# |    27   |    sun    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    31   |     tu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    32   |     yu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    33   |     du    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    34   |   huang   |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    35   |    bai    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    37   |     xu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     0     |     0      |        |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# 118354 dddd
# last time do update area
# -10:0, trace
# now  i do area
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace  | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# |    1    |    wang   |    1     |     1     |  1593364   | -10:0, |    plan    |    -10     |    None   |
# |    2    |     ye    |    1     |     1     |   39065    | -10:0, |    plan    |    -10     |    None   |
# |    3    |    liu    |    1     |     1     |   40244    | -10:0, |    plan    |    -10     |    None   |
# |    4    |     lu    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    5    |     mo    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    6    |   zhang   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    7    |    shi    |    2     |     1     |  1379105   | -10:0, |    plan    |    -10     |    None   |
# |    8    |     wu    |    2     |     1     |   18409    | -10:0, |    plan    |    -10     |    None   |
# |    9    |    xing   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    10   |     hu    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    11   |   zhang   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    12   |     bi    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    13   |     li    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    14   |    zhao   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    15   |    jin    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    16   |    tan    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    17   |    you    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    18   |    qian   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    19   |    song   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    20   |    sun    |    9     |     1     |   323474   | -10:0, |    plan    |    -10     |    None   |
# |    21   |    chen   |    7     |     1     |   15149    | -10:0, |    plan    |    -10     |    None   |
# |    22   |     mu    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    23   |    gao    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    24   |     qi    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    25   |     gu    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    26   |   sheng   |    8     |     1     |   115497   | -10:0, |    plan    |    -10     |    None   |
# |    27   |    sun    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    28   |    deng   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    29   |    yang   |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    30   |    dai    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    31   |     tu    |    9     |     1     |   246440   | -10:0, |    plan    |    -10     |    None   |
# |    32   |     yu    |    9     |     1     |   178058   | -10:0, |    plan    |    -10     |    None   |
# |    33   |     du    |    9     |     1     |   171112   | -10:0, |    plan    |    -10     |    None   |
# |    34   |   huang   |    9     |     1     |   112148   | -10:0, |    plan    |    -10     |    None   |
# |    35   |    bai    |    9     |     1     |   184525   | -10:0, |    plan    |    -10     |    None   |
# |    36   |    mao    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    37   |     xu    |    10    |     1     |   83488    | -10:0, |    plan    |    -10     |    None   |
# |    38   |     lv    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    39   |    qiu    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# |    40   |    yan    |   -10    |     1     |     0      |        |    plan    |     -1     |    None   |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# herereeeeeeeeeeeeeeeeeeeeeeeeeeee 0
#  duplicate
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area | trace  | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# |    1    |    wang   |    1     |     2     |  1586644   | -10:0, |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     2     |   39690    | -10:0, |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     2     |   40482    | -10:0, |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     1     |  1379105   | -10:0, |    plan    |     0      |    None   |
# |    8    |     wu    |    2     |     1     |   18409    | -10:0, |    plan    |     0      |    None   |
# |    9    |    xing   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    20   |    sun    |    9     |     1     |   323474   | -10:0, |    plan    |     0      |    None   |
# |    21   |    chen   |    7     |     1     |   15149    | -10:0, |    plan    |     0      |    None   |
# |    22   |     mu    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    26   |   sheng   |    8     |     1     |   115497   | -10:0, |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    31   |     tu    |    9     |     1     |   246440   | -10:0, |    plan    |     0      |    None   |
# |    32   |     yu    |    9     |     1     |   178058   | -10:0, |    plan    |     0      |    None   |
# |    33   |     du    |    9     |     1     |   171112   | -10:0, |    plan    |     0      |    None   |
# |    34   |   huang   |    9     |     1     |   112148   | -10:0, |    plan    |     0      |    None   |
# |    35   |    bai    |    9     |     1     |   184525   | -10:0, |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    37   |     xu    |    10    |     1     |   83488    | -10:0, |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     1     |     0      |        |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+--------+------------+------------+-----------+
# -1530243 dddd
# last time do update time
#  duplicate
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |   trace    | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     2     |  1586644   |   -10:0,   |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     2     |   39690    |   -10:0,   |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     2     |   40482    |   -10:0,   |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     2     |  1369090   |   -10:0,   |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     2     |   18320    |   -10:0,   |    plan    |     -1     |    None   |
# |    9    |    xing   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    20   |    sun    |    7     |     1     |   207181   | -10:0,9:1, |    plan    |     9      |    None   |
# |    21   |    chen   |    7     |     2     |   15080    |   -10:0,   |    plan    |     -1     |    None   |
# |    22   |     mu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    26   |   sheng   |    8     |     1     |   115497   |   -10:0,   |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    31   |     tu    |    9     |     1     |   246440   |   -10:0,   |    plan    |     0      |    None   |
# |    32   |     yu    |    9     |     1     |   178058   |   -10:0,   |    plan    |     0      |    None   |
# |    33   |     du    |    9     |     1     |   171112   |   -10:0,   |    plan    |     0      |    None   |
# |    34   |   huang   |    9     |     1     |   112148   |   -10:0,   |    plan    |     0      |    None   |
# |    35   |    bai    |    9     |     1     |   184525   |   -10:0,   |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    37   |     xu    |    10    |     1     |   83488    |   -10:0,   |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# -17177 dddd
# last time do update area
# -10:0,9:1, trace
# now  i do area
#  duplicate
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |   trace    | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     2     |  1586644   |   -10:0,   |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     2     |   39690    |   -10:0,   |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     2     |   40482    |   -10:0,   |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    5    |     mo    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     2     |  1369090   |   -10:0,   |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     2     |   18320    |   -10:0,   |    plan    |     -1     |    None   |
# |    9    |    xing   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    20   |    sun    |    7     |     1     |   207181   | -10:0,9:1, |    plan    |     9      |    None   |
# |    21   |    chen   |    7     |     2     |   15080    |   -10:0,   |    plan    |     -1     |    None   |
# |    22   |     mu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    23   |    gao    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    26   |   sheng   |    8     |     2     |   133978   |   -10:0,   |    plan    |     -1     |    None   |
# |    27   |    sun    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    31   |     tu    |    9     |     1     |   246440   |   -10:0,   |    plan    |     0      |    None   |
# |    32   |     yu    |    9     |     1     |   178058   |   -10:0,   |    plan    |     0      |    None   |
# |    33   |     du    |    9     |     1     |   171112   |   -10:0,   |    plan    |     0      |    None   |
# |    34   |   huang   |    9     |     1     |   112148   |   -10:0,   |    plan    |     0      |    None   |
# |    35   |    bai    |    9     |     1     |   184525   |   -10:0,   |    plan    |     0      |    None   |
# |    36   |    mao    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    37   |     xu    |    10    |     1     |   83488    |   -10:0,   |    plan    |     0      |    None   |
# |    38   |     lv    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    39   |    qiu    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# |    40   |    yan    |   -10    |     1     |     0      |            |    plan    |     0      |    None   |
# +---------+-----------+----------+-----------+------------+------------+------------+------------+-----------+
# 114259 dddd
# last time do update area
# -10:0,9:1, trace
# now i do time
# +---------+-----------+----------+-----------+------------+----------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |  trace   | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+----------+------------+------------+-----------+
# |    1    |    wang   |    1     |     2     |  1586644   |  -10:0,  |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     2     |   39690    |  -10:0,  |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     2     |   40482    |  -10:0,  |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    5    |     mo    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    6    |   zhang   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    7    |    shi    |    2     |     2     |  1369090   |  -10:0,  |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     2     |   18320    |  -10:0,  |    plan    |     -1     |    None   |
# |    9    |    xing   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    10   |     hu    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    11   |   zhang   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    12   |     bi    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    13   |     li    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    14   |    zhao   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    15   |    jin    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    16   |    tan    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    17   |    you    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    18   |    qian   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    19   |    song   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    20   |    sun    |    9     |     2     |   321440   |  -10:0,  |    plan    |     -1     |    None   |
# |    21   |    chen   |    7     |     2     |   15080    |  -10:0,  |    plan    |     -1     |    None   |
# |    22   |     mu    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    23   |    gao    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    24   |     qi    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    25   |     gu    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    26   |   sheng   |    8     |     2     |   133978   |  -10:0,  |    plan    |     -1     |    None   |
# |    27   |    sun    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    28   |    deng   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    29   |    yang   |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    30   |    dai    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    31   |     tu    |    9     |     2     |   243322   |  -10:0,  |    plan    |     -1     |    None   |
# |    32   |     yu    |    9     |     2     |   182629   |  -10:0,  |    plan    |     -1     |    None   |
# |    33   |     du    |    9     |     2     |   100205   |  -10:0,  |    plan    |     -1     |    None   |
# |    34   |   huang   |    9     |     2     |   154513   |  -10:0,  |    plan    |     -1     |    None   |
# |    35   |    bai    |    9     |     2     |   178722   |  -10:0,  |    plan    |     -1     |    None   |
# |    36   |    mao    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    37   |     xu    |    10    |     2     |   87946    |  -10:0,  |    plan    |     -1     |    None   |
# |    38   |     lv    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    39   |    qiu    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# |    40   |    yan    |   -10    |     2     |     0      |          |    plan    |     -1     |    None   |
# +---------+-----------+----------+-----------+------------+----------+------------+------------+-----------+
# herereeeeeeeeeeeeeeeeeeeeeeeeeeee 1
# he is a visitor
#  duplicate
# +---------+-----------+----------+-----------+------------+--------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |    trace     | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+--------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     3     |   58229    |    -10:0,    |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     3     |   38938    |    -10:0,    |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     3     |   37748    |    -10:0,    |    plan    |     -1     |    None   |
# |    4    |     lu    |    1     |     1     |    7240    |    -10:2,    |    plan    |    -10     |    None   |
# |    5    |     mo    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    6    |   zhang   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    7    |    shi    |    2     |     3     |  1444225   |    -10:0,    |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     2     |   18320    |    -10:0,    |    plan    |     0      |    None   |
# |    9    |    xing   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    10   |     hu    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    11   |   zhang   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    12   |     bi    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    13   |     li    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    14   |    zhao   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    15   |    jin    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    16   |    tan    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    17   |    you    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    18   |    qian   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    19   |    song   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    20   |    sun    |    7     |     1     |   220825   |  -10:0, 9:2, |    plan    |     9      |    None   |
# |    21   |    chen   |    7     |     3     |   15317    |    -10:0,    |    plan    |     -1     |    None   |
# |    22   |     mu    |    7     |     1     |   18245    |    -10:2,    |    plan    |    -10     |    None   |
# |    23   |    gao    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    24   |     qi    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    25   |     gu    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    26   |   sheng   |    8     |     2     |   133978   |    -10:0,    |    plan    |     0      |    None   |
# |    27   |    sun    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    28   |    deng   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    29   |    yang   |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    30   |    dai    |   -10    |     2     |     0      |              |    plan    |     0      |    None   |
# |    31   |     tu    |    9     |     2     |   243322   |    -10:0,    |    plan    |     0      |    None   |
# |    32   |     yu    |    9     |     2     |   182629   |    -10:0,    |    plan    |     0      |    None   |
# |    33   |     du    |    9     |     2     |   100205   |    -10:0,    |    plan    |     0      |    None   |
# |    34   |   huang   |    9     |     2     |   154513   |    -10:0,    |    plan    |     0      |    None   |
# ...
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# 104353 dddd
# last time do update area
#   -10:0, 9:3, trace
# now i do time
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |      trace       | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     4     |   58376    |      -10:0,      |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     4     |   38938    |      -10:0,      |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     4     |   36397    |      -10:0,      |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     1     |     0      |    -10:2,1:1,    |    plan    |     1      |    None   |
# |    5    |     mo    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    6    |   zhang   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    7    |    shi    |    2     |     4     |  1425825   |      -10:0,      |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     1     |  1450117   | -10:0,2:2,-10:1, |    plan    |    -10     |    None   |
# |    9    |    xing   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    10   |     hu    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    11   |   zhang   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    12   |     bi    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    13   |     li    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    14   |    zhao   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    15   |    jin    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    16   |    tan    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    17   |    you    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    18   |    qian   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    19   |    song   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    20   |    sun    |    9     |     4     |   325557   |       -10:0,     |    plan    |     -1     |    None   |
# |    21   |    chen   |    7     |     4     |   15625    |      -10:0,      |    plan    |     -1     |    None   |
# |    22   |     mu    |   -10    |     1     |     0      |    -10:2,7:1,    |    plan    |     7      |    None   |
# |    23   |    gao    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    24   |     qi    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    25   |     gu    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    26   |   sheng   |   -10    |     2     |     0      |    -10:0,8:2,    |    plan    |     -1     |    None   |
# |    27   |    sun    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    28   |    deng   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    29   |    yang   |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    30   |    dai    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    31   |     tu    |    9     |     4     |   204642   |      -10:0,      |    plan    |     -1     |    None   |
# |    32   |     yu    |    9     |     4     |   176416   |      -10:0,      |    plan    |     -1     |    None   |
# |    33   |     du    |    9     |     4     |   140858   |      -10:0,      |    plan    |     -1     |    None   |
# |    34   |   huang   |    9     |     4     |   145522   |      -10:0,      |    plan    |     -1     |    None   |
# |    35   |    bai    |    9     |     4     |   162485   |      -10:0,      |    plan    |     -1     |    None   |
# |    36   |    mao    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    37   |     xu    |    10    |     4     |   85034    |      -10:0,      |    plan    |     -1     |    None   |
# |    38   |     lv    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    39   |    qiu    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# |    40   |    yan    |   -10    |     4     |     0      |                  |    plan    |     -1     |    None   |
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# herereeeeeeeeeeeeeeeeeeeeeeeeeeee 3
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |      trace       | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     5     |   58676    |      -10:0,      |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     5     |   39065    |      -10:0,      |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     5     |   35176    |      -10:0,      |    plan    |     -1     |    None   |
# |    4    |     lu    |   -10    |     2     |     0      |    -10:2,1:1,    |    plan    |     -1     |    None   |
# |    5    |     mo    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    6    |   zhang   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    7    |    shi    |   -10    |     1     |     0      |    -10:0,2:4,    |    plan    |     2      |    None   |
# |    8    |     wu    |    2     |     2     |  1299482   | -10:0,2:2,-10:1, |    plan    |     -1     |    None   |
# |    9    |    xing   |    2     |     1     |  1317901   |      -10:4,      |    plan    |    -10     |    None   |
# |    10   |     hu    |    2     |     1     |   19720    |      -10:4,      |    plan    |    -10     |    None   |
# |    11   |   zhang   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    12   |     bi    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    13   |     li    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    14   |    zhao   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    15   |    jin    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    16   |    tan    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    17   |    you    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    18   |    qian   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    19   |    song   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    20   |    sun    |    7     |     1     |   217876   |     -10:0, 9:4,  |    plan    |     9      |    None   |
# |    21   |    chen   |    7     |     5     |   19594    |      -10:0,      |    plan    |     -1     |    None   |
# |    22   |     mu    |    7     |     1     |   18884    | -10:2,7:1,-10:1, |    plan    |    -10     |    None   |
# |    23   |    gao    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    24   |     qi    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    25   |     gu    |    8     |     1     |   205088   |      -10:4,      |    plan    |    -10     |    None   |
# |    26   |   sheng   |   -10    |     3     |     0      |    -10:0,8:2,    |    plan    |     -1     |    None   |
# |    27   |    sun    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    28   |    deng   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    29   |    yang   |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    30   |    dai    |    9     |     1     |   324641   |      -10:4,      |    plan    |    -10     |    None   |
# |    31   |     tu    |    9     |     5     |   203681   |      -10:0,      |    plan    |     -1     |    None   |
# |    32   |     yu    |    9     |     5     |   175860   |      -10:0,      |    plan    |     -1     |    None   |
# |    33   |     du    |    9     |     5     |   152129   |      -10:0,      |    plan    |     -1     |    None   |
# |    34   |   huang   |    9     |     5     |   148096   |      -10:0,      |    plan    |     -1     |    None   |
# |    35   |    bai    |    9     |     5     |   147745   |      -10:0,      |    plan    |     -1     |    None   |
# |    36   |    mao    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    37   |     xu    |    10    |     5     |   83924    |      -10:0,      |    plan    |     -1     |    None   |
# |    38   |     lv    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    39   |    qiu    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# |    40   |    yan    |   -10    |     5     |     0      |                  |    plan    |     -1     |    None   |
# +---------+-----------+----------+-----------+------------+------------------+------------+------------+-----------+
# herereeeeeeeeeeeeeeeeeeeeeeeeeeee 4
# +---------+-----------+----------+-----------+------------+----------------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |        trace         | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+----------------------+------------+------------+-----------+
# |    1    |    wang   |    1     |     6     |   58370    |        -10:0,        |    plan    |     -1     |    None   |
# |    2    |     ye    |    1     |     6     |   39325    |        -10:0,        |    plan    |     -1     |    None   |
# |    3    |    liu    |    1     |     6     |   35258    |        -10:0,        |    plan    |     -1     |    None   |
# |    4    |     lu    |    1     |     1     |    7816    |   -10:2,1:1,-10:2,   |    plan    |    -10     |    None   |
# |    5    |     mo    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    6    |   zhang   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    7    |    shi    |   -10    |     2     |     0      |      -10:0,2:4,      |    plan    |     -1     |    None   |
# |    8    |     wu    |    2     |     3     |  1318321   |   -10:0,2:2,-10:1,   |    plan    |     -1     |    None   |
# |    9    |    xing   |    2     |     2     |  1220425   |        -10:4,        |    plan    |     -1     |    None   |
# |    10   |     hu    |   -10    |     1     |     0      |      -10:4,2:1,      |    plan    |     2      |    None   |
# |    11   |   zhang   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    12   |     bi    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    13   |     li    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    14   |    zhao   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    15   |    jin    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    16   |    tan    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    17   |    you    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    18   |    qian   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    19   |    song   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    20   |    sun    |    7     |     2     |   207520   |       -10:0, 9:4,    |    plan    |     -1     |    None   |
# |    21   |    chen   |    7     |     6     |   18793    |        -10:0,        |    plan    |     -1     |    None   |
# |    22   |     mu    |   -10    |     1     |     0      | -10:2,7:1,-10:1,7:1, |    plan    |     7      |    None   |
# |    23   |    gao    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    24   |     qi    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    25   |     gu    |    8     |     2     |   210033   |        -10:4,        |    plan    |     -1     |    None   |
# |    26   |   sheng   |   -10    |     4     |     0      |      -10:0,8:2,      |    plan    |     -1     |    None   |
# |    27   |    sun    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    28   |    deng   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    29   |    yang   |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    30   |    dai    |    9     |     2     |   326005   |        -10:4,        |    plan    |     -1     |    None   |
# |    31   |     tu    |    9     |     6     |   205465   |        -10:0,        |    plan    |     -1     |    None   |
# |    32   |     yu    |    9     |     6     |   172264   |        -10:0,        |    plan    |     -1     |    None   |
# |    33   |     du    |    9     |     6     |   161704   |        -10:0,        |    plan    |     -1     |    None   |
# |    34   |   huang   |    9     |     6     |   164645   |        -10:0,        |    plan    |     -1     |    None   |
# |    35   |    bai    |    9     |     6     |   163332   |        -10:0,        |    plan    |     -1     |    None   |
# |    36   |    mao    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    37   |     xu    |    10    |     6     |   67541    |        -10:0,        |    plan    |     -1     |    None   |
# |    38   |     lv    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    39   |    qiu    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# |    40   |    yan    |   -10    |     6     |     0      |                      |    plan    |     -1     |    None   |
# +---------+-----------+----------+-----------+------------+----------------------+------------+------------+-----------+
# herereeeeeeeeeeeeeeeeeeeeeeeeeeee 5

# %%
class App:
    def __init__(self, root):
        root.title('test')
        frame = tk.Frame(root)
        frame.pack()
        self.hi_there = tk.Button(frame, text="click me ", fg="blue", command=self.say_hi)
        self.hi_there.pack(side=tk.LEFT)
    def say_hi(self):
        user_id=input('what is your number?')
        piece_name=input('what piece have you taken ?')
        
        lib.workpiece(conn,str(piece_name),int(user_id))
        print('complete')

# %%
root = tk.Tk()
app = App(root)
if app==1:
    print('right')
root.mainloop()
# Out:
# what is your number?1
# what piece have you taken ?sd
# +---------+-----------+----------+-----------+------------+-----------------+------------+------------+-----------+
# | user_id | user_name | area_now | stay_time | frame_area |      trace      | plan_trace | has_update | workpiece |
# +---------+-----------+----------+-----------+------------+-----------------+------------+------------+-----------+
# |    1    |    wang   |    a1    |     4     |   57305    |      od:0,      |    plan    |     1      |     sd    |
# |    2    |     ye    |    a1    |     4     |   39065    |      od:0,      |    plan    |     1      |    None   |
# |    3    |    liu    |    a1    |     4     |   40244    |      od:0,      |    plan    |     1      |    None   |
# |    4    |     lu    |    od    |     1     |     0      |    od:2,a1:1,   |    plan    |     1      |    None   |
# |    5    |     mo    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    6    |   zhang   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    7    |    shi    |    a2    |     4     |  1379105   |      od:0,      |    plan    |     1      |    None   |
# |    8    |     wu    |    a2    |     1     |  1450117   | od:0,a2:2,od:1, |    plan    |     1      |    None   |
# |    9    |    xing   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    10   |     hu    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    11   |   zhang   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    12   |     bi    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    13   |     li    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    14   |    zhao   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    15   |    jin    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    16   |    tan    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    17   |    you    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    18   |    qian   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    19   |    song   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    20   |    sun    |    a7    |     4     |   205120   |      od:0,      |    plan    |     1      |    None   |
# |    21   |    chen   |    a7    |     4     |   15149    |      od:0,      |    plan    |     1      |    None   |
# |    22   |     mu    |    od    |     1     |     0      |    od:2,a7:1,   |    plan    |     1      |    None   |
# |    23   |    gao    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    24   |     qi    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    25   |     gu    |    a8    |     4     |   185861   |      od:0,      |    plan    |     1      |    None   |
# |    26   |   sheng   |    od    |     2     |     0      |    od:0,a8:2,   |    plan    |     1      |    None   |
# |    27   |    sun    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    28   |    deng   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    29   |    yang   |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    30   |    dai    |    a9    |     3     |   321440   |      od:1,      |    plan    |     1      |    None   |
# |    31   |     tu    |    a9    |     4     |   246440   |      od:0,      |    plan    |     1      |    None   |
# |    32   |     yu    |    a9    |     4     |   178058   |      od:0,      |    plan    |     1      |    None   |
# |    33   |     du    |    a9    |     4     |   171112   |      od:0,      |    plan    |     1      |    None   |
# |    34   |   huang   |    a9    |     4     |   112148   |      od:0,      |    plan    |     1      |    None   |
# |    35   |    bai    |    a9    |     4     |   184525   |      od:0,      |    plan    |     1      |    None   |
# |    36   |    mao    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    37   |     xu    |   a10    |     4     |   83488    |      od:0,      |    plan    |     1      |    None   |
# |    38   |     lv    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    39   |    qiu    |    od    |     4     |     0      |                 |    plan    |     1      |    None   |
# |    40   |    yan    |    od    |     3     |     0      |    od:0,a9:1,   |    plan    |     1      |    None   |
# +---------+-----------+----------+-----------+------------+-----------------+------------+------------+-----------+
# complete
